# %%
import numpy as np
from matplotlib import pyplot as plt
import math
import heat150 as sys

T_init=sys.get_T_init()
plt.imshow(T_init, cmap='bwr')

# %%
T_next=sys.next_T(T_init)
plt.imshow(T_next,cmap='bwr')
T_next.max()-T_init.max()
# Out:
# 0.1894701703474766

# %%
T_iter=T_init
Tmax=list()
for i in range(int(6*6*300)):
    Tmax.append(T_iter.max())
    T_iter=sys.next_T(T_iter)
    if Tmax[-1]>80+sys.T0:
        print('在 '+str(i)+' 步超过80度！')
        break
    pass
Tmax=np.array(Tmax)-sys.T0
print(T_iter.max()-sys.T0)
plt.imshow(T_iter,cmap='bwr')
plt.show()
plt.plot(Tmax)
# Out:
# 55.81198326503528

# %%
T_iter1=T_iter
Tmax1=list()
for i in range(int(6*6*300)):
    Tmax1.append(T_iter1.max())
    T_iter1=sys.next_T(T_iter1)
    if Tmax1[-1]>80+sys.T0:
        print('在 '+str(i)+' 步超过80度！')
        break
    pass
Tmax1=np.array(Tmax1)-sys.T0
print(T_iter1.max()-sys.T0)
plt.imshow(T_iter1,cmap='bwr')
plt.show()
plt.plot(Tmax1)
# Out:
# 63.45440825381678

# %%
T_iter2=T_iter1
Tmax2=list()
for i in range(int(6*6*300)):
    Tmax2.append(T_iter2.max())
    T_iter2=sys.next_T(T_iter2)
    if Tmax2[-1]>80+sys.T0:
        print('在 '+str(i)+' 步超过80度！')
        break
    pass
Tmax2=np.array(Tmax2)-sys.T0
print(T_iter2.max()-sys.T0)
plt.imshow(T_iter2,cmap='bwr')
plt.show()
plt.plot(Tmax2)
# Out:
# 67.94509421159012

# %%
T_iter3=T_iter2
Tmax3=list()
for i in range(int(6*6*300)):
    Tmax3.append(T_iter3.max())
    T_iter3=sys.next_T(T_iter3)
    if Tmax3[-1]>80+sys.T0:
        print('在 '+str(i)+' 步超过80度！')
        break
    pass
Tmax3=np.array(Tmax3)-sys.T0
print(T_iter3.max()-sys.T0)
plt.imshow(T_iter3,cmap='bwr')
plt.show()
plt.plot(Tmax3)
# Out:
# 70.53098666013256

# %%
T_iter4=T_iter3
Tmax4=list()
for i in range(int(6*6*300)):
    Tmax4.append(T_iter4.max())
    T_iter4=sys.next_T(T_iter4)
    if Tmax4[-1]>80+sys.T0:
        print('在 '+str(i)+' 步超过80度！')
        break
    pass
Tmax4=np.array(Tmax4)-sys.T0
print(T_iter4.max()-sys.T0)
plt.imshow(T_iter4,cmap='bwr')
plt.show()
plt.plot(Tmax4)
# Out:
# 71.94275089784065

# %%
T_iter5=T_iter4
Tmax5=list()
for i in range(int(6*6*300)):
    Tmax5.append(T_iter5.max())
    T_iter5=sys.next_T(T_iter5)
    if Tmax5[-1]>80+sys.T0:
        print('在 '+str(i)+' 步超过80度！')
        break
    pass
Tmax5=np.array(Tmax5)-sys.T0
print(T_iter5.max()-sys.T0)
plt.imshow(T_iter5,cmap='bwr')
plt.show()
plt.plot(Tmax5)
# Out:
# 72.66541340413823

# %%
T_iter6=T_iter5
Tmax6=list()
for i in range(int(6*6*300)):
    Tmax6.append(T_iter6.max())
    T_iter6=sys.next_T(T_iter6)
    if Tmax6[-1]>80+sys.T0:
        print('在 '+str(i)+' 步超过80度！')
        break
    pass
Tmax6=np.array(Tmax6)-sys.T0
print(T_iter6.max()-sys.T0)
plt.imshow(T_iter6,cmap='bwr')
plt.show()
plt.plot(Tmax6)
# Out:
# 73.01438791925193

# %%
TTT=np.r_[Tmax,Tmax1,Tmax2,Tmax3,Tmax4,Tmax5,Tmax6]
ttt=7*6*6*300*100/60/60/24
TTTconst=TTT[-1]+np.zeros(TTT.size)
ddd=np.linspace(0,ttt,TTT.size)
plt.plot(ddd,TTT,label='$T_{max}$-day')
plt.plot(ddd,TTTconst,label='$T_{final}=$'+str(int(TTT[-1]))+'$\degree C$')
plt.legend(fontsize='x-large')
plt.grid(True)
plt.title('$T_{max}$ with Days When Number=150')
plt.xlabel('t / Days')
plt.ylabel('$T_{max}$ / $\degree C$')
plt.savefig('150.png',format='png')

# %%
import seaborn as sns
sns.heatmap(T_iter6.T-sys.T0,cmap='RdBu_r')
plt.title('Stable Temperature Distribution\n When Number=150 at Day 88')
plt.axis('off')
plt.savefig('150T.png',format='png')
