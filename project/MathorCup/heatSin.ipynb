# %%
import numpy as np
from matplotlib import pyplot as plt
import math
import heatSin as sys
import seaborn as sns

T_init=sys.get_T_init()
plt.imshow(T_init, cmap='bwr')

# %%
T_next=sys.next_T_t(T_init,0)
plt.imshow(T_next,cmap='bwr')
T_next.max()-T_init.max()
# Out:
# 0.20210151503732732

# %%
T_iter=T_init
Tmax=list()
for i in range(int(6*6*300)):
    Tmax.append(T_iter.max())
    T_iter=sys.next_T_t(T_iter,i)
    if Tmax[-1]>80+sys.T0:
        print('在 '+str(i)+' 步超过80度！')
        break
    pass
Tmax=np.array(Tmax)-sys.T0
print(T_iter.max()-sys.T0)
plt.imshow(T_iter,cmap='bwr')
plt.show()
plt.plot(Tmax)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-fda423f5b13d> in <module>
#       3 for i in range(int(6*6*300)):
#       4     Tmax.append(T_iter.max())
# ----> 5     T_iter=sys.next_T(T_iter,i)
#       6     if Tmax[-1]>80+sys.T0:
#       7         print('在 '+str(i)+' 步超过80度！')
#
# TypeError: next_T() takes 1 positional argument but 2 were given
