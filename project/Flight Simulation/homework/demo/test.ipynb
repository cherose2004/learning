# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
from tool import *

# %%
name='demo2.png'
a=OCR(name,up=10,limit=0.34)
plt.imshow(a.filter1,cmap=plt.cm.hot)
plt.scatter(a.N0,a.M0,s=100)
plt.show()
plt.scatter(a.xiyj[0],a.xiyj[1])
plt.show()

# %%
a.set_p1(350,10)
a.set_p2(350,22,784,125)
a.set_p3(800,10,0,552)
a.process()

# %%
plt.plot(a.xy[0],a.xy[1])
plt.grid(True)
plt.show()

# %%
data=a.xy
data
# Out:
# array([[400.51020408, 401.08418367, 401.65816327, 459.63010204,
#         460.20408163, 460.77806122, 539.41326531, 539.9872449 ,
#         540.56122449, 541.13520408, 581.8877551 , 582.46173469,
#         601.97704082, 602.55102041, 622.64030612, 623.21428571,
#         632.39795918, 632.97193878, 633.54591837, 634.11989796,
#         634.69387755, 636.41581633, 636.98979592, 637.56377551,
#         638.1377551 , 638.71173469, 639.28571429, 641.58163265,
#         642.15561224, 642.72959184, 643.30357143, 686.92602041,
#         687.5       , 688.07397959, 707.58928571, 708.16326531,
#         723.08673469, 723.66071429, 724.23469388, 727.67857143,
#         728.25255102, 753.50765306, 754.08163265, 754.65561224,
#         755.22959184, 755.80357143, 758.67346939, 759.24744898,
#         759.82142857, 762.69132653, 763.26530612, 763.83928571,
#         767.85714286, 768.43112245, 769.00510204, 769.57908163,
#         772.44897959, 773.02295918, 773.59693878, 774.17091837,
#         774.74489796, 775.31887755, 778.7627551 , 779.33673469,
#         787.37244898, 787.94642857, 788.52040816, 789.09438776],
#        [ 12.30751501,  12.30758703,  12.30765906,  13.02081633,
#          13.02088836,  13.02096038,  13.90612245,  13.90619448,
#          13.92038415,  13.92045618,  15.01262905,  15.02681873,
#          16.257503  ,  16.25757503,  17.60127251,  17.61546218,
#          17.95543818,  17.96962785,  17.99793517,  18.0262425 ,
#          18.04043217,  18.12535414,  18.13954382,  18.15373349,
#          18.16792317,  18.19623049,  18.21042017,  18.29541417,
#          18.30960384,  18.30967587,  18.32386555,  18.95051621,
#          18.95058824,  18.95066026,  19.23546218,  19.23553421,
#          19.46328932,  19.46336134,  19.46343337,  19.52033613,
#          19.52040816,  19.91887155,  19.91894358,  19.91901561,
#          19.91908764,  19.91915966,  19.9759904 ,  19.97606242,
#          19.97613445,  20.03296519,  20.03303721,  20.03310924,
#          20.11831933,  20.11839136,  20.11846339,  20.11853541,
#          20.17536615,  20.17543818,  20.18962785,  20.18969988,
#          20.20388956,  20.20396158,  20.26086435,  20.26093637,
#          20.40312125,  20.40319328,  20.40326531,  20.40333733]])
