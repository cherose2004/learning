# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
from tool import *

# %%
name='demo2.png'
a=OCR(name,up=10,limit=0.34)
plt.imshow(a.pic)
plt.show()
plt.imshow(a.filter1,cmap=plt.cm.hot)
plt.scatter(a.N0,a.M0,s=100)
plt.show()
plt.scatter(a.xiyj[0],a.xiyj[1])
plt.show()

# %%
a.set_p1(350,10)
a.set_p2(350,22,784,125)
a.set_p3(800,10,0,552)
a.process(360,11)

# %%
plt.plot(a.xy[0],a.xy[1])
plt.grid(True)
plt.show()

# %%
data=a.xy
data
# Out:
# array([[401.08418367, 460.20408163, 491.19897959, 539.9872449 ,
#         540.56122449, 551.46683673, 581.8877551 , 582.46173469,
#         597.95918367, 601.97704082, 602.55102041, 617.4744898 ,
#         620.91836735, 621.49234694, 622.06632653, 622.64030612,
#         623.21428571, 623.78826531, 624.93622449, 632.97193878,
#         633.54591837, 634.11989796, 634.69387755, 636.98979592,
#         637.56377551, 639.28571429, 642.15561224, 642.72959184,
#         661.09693878, 685.77806122, 686.92602041, 687.5       ,
#         708.16326531, 723.66071429, 727.67857143, 754.65561224,
#         759.24744898, 763.26530612, 769.00510204, 773.59693878,
#         774.17091837, 774.74489796, 779.33673469, 788.52040816,
#         793.1122449 ],
#        [ 12.30758703,  13.02088836,  13.36360144,  13.89207683,
#          13.9345018 ,  14.04881152,  14.9985114 ,  15.02681873,
#          15.98876351,  16.24338535,  16.24345738,  17.23356543,
#          17.45987995,  17.48818727,  17.53061224,  17.57303721,
#          17.60134454,  17.62965186,  17.67214886,  17.9555102 ,
#          17.99793517,  18.0262425 ,  18.05454982,  18.12542617,
#          18.16785114,  18.21042017,  18.28136855,  18.32379352,
#          18.58021609,  18.90801921,  18.93639856,  18.96470588,
#          19.23553421,  19.46336134,  19.52033613,  19.91901561,
#          19.97606242,  20.03303721,  20.11846339,  20.16139256,
#          20.18969988,  20.2180072 ,  20.26093637,  20.40326531,
#          20.46031212]])
