# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
import tool as tol

# %%
name='GroundEffectK.png'
a=tol.OCR(name,up=4,limit=0.34)
plt.imshow(a.pic)
plt.show()
plt.imshow(a.filter2,cmap=plt.cm.hot)
plt.scatter(a.N0,a.M0,s=100)
plt.show()
plt.scatter(a.xiyj[0],a.xiyj[1])
plt.show()

# %%
b=a.filter2
print(a.M0,a.N0)
# Out:
# 663 46

# %%
a.set_p1(0,0)
a.set_p2(0,90,46,17)
a.set_p3(1,0,403,663)
a.process(0.05,1)

# %%
plt.plot(a.xy[0],a.xy[1])
plt.grid(True)
plt.show()

# %%
xx=np.arange(0.05,0.7,0.01)
yy=np.zeros(xx.size)
for i in range(xx.size):
    yy[i]=tol.Interpoly(xx[i],a.xy[0],a.xy[1])
    pass
plt.plot(xx,yy)
