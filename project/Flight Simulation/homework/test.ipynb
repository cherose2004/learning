# %%
import ADP as ad

# %%
name = 'ex4.png'
a = ad.Pic(name,up=5)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(a.binary,cmap=plt.cm.hot)
plt.scatter(a.N0,a.M0,color='g',s=200) #注意顺序

# %%
a.Filter('mm',limit=0.3)

# %%
plt.scatter(a.xiyj[0],a.xiyj[1],s=100)

# %%
print(a.M0,a.N0)
# Out:
# 784 550

# %%
b = a.fil

# %%
a.set_p1(350,10)
a.set_p2(350,22,784,125)
a.set_p3(800,10,0,552)
a.get_Trans()

# %%
plt.scatter(a.xy_init[0],a.xy_init[1],s=100)

# %%
a.process(360,10.5)

# %%
plt.scatter(a.xy[0],a.xy[1],s=100)

# %%
plt.plot(a.xy[0],a.xy[1])

# %%
ad.writeSQL(a.xy[0],a.xy[1],'test','a')
# Out:
# successfully create test
# successfully create a

# %%
del a , b , name

# %%
x,y=ad.readSQL('test','a')
plt.plot(x,y)

# %%
del x,y

# %%
import numpy as np
def func_a(xin):
    x , y =ad.readSQL('test','a')
    if type(xin) == np.ndarray:
        tmp = np.zeros(xin.shape)
        for i in range(tmp.size):
            tmp[i] = ad.Interpoly(xin[i],x,y)
            pass
        return tmp
        pass
    else:
        return ad.Interpoly(xin,x,y)
        pass

# %%
x = np.arange(400,700,10)
y = func_a(x)
plt.plot(x,y)
