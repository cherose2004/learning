# %% [markdown]
# # P181-7-8

# %%
import FEM as fem
import numpy as np
NaN = np.nan

# %%
P = 24e3
a = 1
f = 0.01
E = 200e9
t = 0.01
G = E*f/t/a/10

node1 = fem.Node(-a , -a , Px = 0 , Py = 0)
node2 = fem.Node(0 , -a , Px = 0 , Py = 0)
node3 = fem.Node(a , -a , Px = 0 , Py = 0)
node4 = fem.Node(-a , 0 , u = 0 , v = 0)
node5 = fem.Node(0 , 0 , Px = 0 , Py = 0)
node6 = fem.Node(a , 0 , Px = P , v = 0)
node7 = fem.Node(-a , a , Px = 0 , Py = 0)
node8 = fem.Node(0 , a , Px = 0 , Py = 0)
node9 = fem.Node(a , a , Px = 0 , Py = 0)
nodelist = [node1 , node2 , node3 , node4 , node5 , node6 , node7 , node8 , node9]

# %%
sys = fem.SystemTruss(nodelist)

sys.Connect(1 , 2 , E , f)
sys.Connect(2 , 3 , E , f)
sys.Connect(4 , 5 , E , f)
sys.Connect(5 , 6 , E , f)
sys.Connect(7 , 8 , E , f)
sys.Connect(8 , 9 , E , f)
sys.Connect(1 , 4 , E , f)
sys.Connect(4 , 7 , E , f)
sys.Connect(2 , 5 , E , f)
sys.Connect(5 , 8 , E , f)
sys.Connect(3 , 6 , E , f)
sys.Connect(6 , 9 , E , f)

sys.SetSheet(1 , 2 , 5 , 4 , G , t)
sys.SetSheet(2 , 3 , 6 , 5 , G , t)
sys.SetSheet(4 , 5 , 8 , 7 , G , t)
sys.SetSheet(5 , 6 , 9 , 8 , G , t)

sys.Generate()
# Out:
# Successfully Build The Truss System!
# Successfully Generate Matrix K!

# %%
print(np.floor(sys.K/1e7))
# Out:
# [[ 205.    5. -195.   -5.    0.    0.   -5.    5.   -5.   -5.    0.    0.
#      0.    0.    0.    0.    0.    0.]
#  [   5.  205.    5.   -5.    0.    0.   -5. -195.   -5.   -5.    0.    0.
#      0.    0.    0.    0.    0.    0.]
#  [-195.    5.  410.    0. -195.   -5.   -5.    5.  -10.    0.   -5.   -5.
#      0.    0.    0.    0.    0.    0.]
#  [  -5.   -5.    0.  210.    5.   -5.    5.   -5.    0. -190.   -5.   -5.
#      0.    0.    0.    0.    0.    0.]
#  [   0.    0. -195.    5.  205.   -5.    0.    0.   -5.    5.   -5.   -5.
#      0.    0.    0.    0.    0.    0.]
#  [   0.    0.   -5.   -5.   -5.  205.    0.    0.    5.   -5.    5. -195.
#      0.    0.    0.    0.    0.    0.]
#  [  -5.   -5.   -5.    5.    0.    0.  210.    0. -190.    0.    0.    0.
#     -5.    5.   -5.   -5.    0.    0.]
#  [   5. -195.    5.   -5.    0.    0.    0.  410.    0.  -10.    0.    0.
#     -5. -195.   -5.   -5.    0.    0.]
#  [  -5.   -5.  -10.    0.   -5.    5. -190.    0.  420.    0. -190.    0.
#     -5.    5.  -10.    0.   -5.   -5.]
#  [  -5.   -5.    0. -190.    5.   -5.    0.  -10.    0.  420.    0.  -10.
#      5.   -5.    0. -190.   -5.   -5.]
#  [   0.    0.   -5.   -5.   -5.    5.    0.    0. -190.    0.  210.    0.
#      0.    0.   -5.    5.   -5.   -5.]
#  [   0.    0.   -5.   -5.   -5. -195.    0.    0.    0.  -10.    0.  410.
#      0.    0.    5.   -5.    5. -195.]
#  [   0.    0.    0.    0.    0.    0.   -5.   -5.   -5.    5.    0.    0.
#    205.   -5. -195.    5.    0.    0.]
#  [   0.    0.    0.    0.    0.    0.    5. -195.    5.   -5.    0.    0.
#     -5.  205.   -5.   -5.    0.    0.]
#  [   0.    0.    0.    0.    0.    0.   -5.   -5.  -10.    0.   -5.    5.
#   -195.   -5.  410.    0. -195.    5.]
#  [   0.    0.    0.    0.    0.    0.   -5.   -5.    0. -190.    5.   -5.
#      5.   -5.    0.  210.   -5.   -5.]
#  [   0.    0.    0.    0.    0.    0.    0.    0.   -5.   -5.   -5.    5.
#      0.    0. -195.   -5.  205.    5.]
#  [   0.    0.    0.    0.    0.    0.    0.    0.   -5.   -5.   -5. -195.
#      0.    0.    5.   -5.    5.  205.]]

# %%
sys.Solve()
# Out:
# Successfully Solve the Truss System!

# %%
print(sys.Report)
# Out:
# Reprort : Information of This Truss System
#
# ************************************************************
# q of 1,2,5,4:
# -1043.4782608695643 N/m
#
# q of 2,3,6,5:
# 1043.4782608695652 N/m
#
# q of 4,5,8,7:
# 1043.4782608695618 N/m
#
# q of 5,6,9,8:
# -1043.4782608695677 N/m
#
# ------------------------------------------------------------
# Node1 :
#  Position :
# (-1,-1)
# External Load :
# Horizontal Load Px = 0.0 N
# Vertical Load Py = 0.0 N
# Displacement :
# Horizontal Displacement u = 1.1217391304347819e-05 m
# Vertical Displacement v = -2.6086956521739105e-07 m
# ------------------------------------------------------------
# Node2 :
#  Position :
# (0,-1)
# External Load :
# Horizontal Load Px = 0.0 N
# Vertical Load Py = 0.0 N
# Displacement :
# Horizontal Displacement u = 1.1478260869565212e-05 m
# Vertical Displacement v = 5.217391304347821e-07 m
# ------------------------------------------------------------
# Node3 :
#  Position :
# (1,-1)
# External Load :
# Horizontal Load Px = 0.0 N
# Vertical Load Py = 0.0 N
# Displacement :
# Horizontal Displacement u = 1.17391304347826e-05 m
# Vertical Displacement v = -2.608695652173914e-07 m
# ------------------------------------------------------------
# Node4 :
#  Position :
# (-1,0)
# External Load :
# Horizontal Load Px = -23999.99999999999 N
# Vertical Load Py = 2.170708057747106e-12 N
# Displacement :
# Horizontal Displacement u = 0.0 m
# Vertical Displacement v = 0.0 m
# ------------------------------------------------------------
# Node5 :
#  Position :
# (0,0)
# External Load :
# Horizontal Load Px = 0.0 N
# Vertical Load Py = 0.0 N
# Displacement :
# Horizontal Displacement u = 1.1478260869565213e-05 m
# Vertical Displacement v = -4.446524937437108e-22 m
# ------------------------------------------------------------
# Node6 :
#  Position :
# (1,0)
# External Load :
# Horizontal Load Px = 24000.0 N
# Vertical Load Py = -2.1032064978498966e-12 N
# Displacement :
# Horizontal Displacement u = 2.2956521739130427e-05 m
# Vertical Displacement v = 0.0 m
# ------------------------------------------------------------
# Node7 :
#  Position :
# (-1,1)
# External Load :
# Horizontal Load Px = 0.0 N
# Vertical Load Py = 0.0 N
# Displacement :
# Horizontal Displacement u = 1.1217391304347809e-05 m
# Vertical Displacement v = 2.6086956521739057e-07 m
# ------------------------------------------------------------
# Node8 :
#  Position :
# (0,1)
# External Load :
# Horizontal Load Px = 0.0 N
# Vertical Load Py = 0.0 N
# Displacement :
# Horizontal Displacement u = 1.1478260869565198e-05 m
# Vertical Displacement v = -5.217391304347827e-07 m
# ------------------------------------------------------------
# Node9 :
#  Position :
# (1,1)
# External Load :
# Horizontal Load Px = 0.0 N
# Vertical Load Py = 0.0 N
# Displacement :
# Horizontal Displacement u = 1.1739130434782589e-05 m
# Vertical Displacement v = 2.608695652173919e-07 m
# ************************************************************

# %%
sys.SetPrecison(3)
sys.ExportFigure()
# Out:
# Successfully Save Figure to Figure_of_Truss_System.png!
